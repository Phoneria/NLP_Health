# %%
import pandas as pd
import os
import glob
from tqdm import tqdm
import requests
from bs4 import BeautifulSoup
import re

# %%
# Specify the directory containing Excel files
directory = r"C:\Users\Nasip-PC\Desktop\Dosyalar\Kodlar\NLP\Data\Raw"

# Get all Excel files in the directory
xlsx_files = glob.glob(os.path.join(directory, "*.xlsx"))

# %%
# Function to fetch webpage text
def fetch_webpage_text(url):
    try:
        headers = {'User-Agent': 'Mozilla/5.0'}  # Some websites block requests without user-agent
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()

        # Parse the HTML content
        soup = BeautifulSoup(response.text, "html.parser")

        # Extract text from the page
        text = soup.get_text(separator=" ", strip=True)
        return text

    except requests.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None  # Return None if there was an error
    

def extract_values(text, keys):
    if not isinstance(text, str):  # Ensure it's a string
        return {key: None for key in keys}

    extracted_data = {}

    # Normalize text by removing extra whitespace (optional but helpful)
    text = re.sub(r'\s+', ' ', text)

    for i, key in enumerate(keys):
        next_key = keys[i + 1] if i + 1 < len(keys) else None

        # Create pattern to extract value between key and next_key
        if next_key:
            pattern = rf"{re.escape(key)}\s*(.*?)(?={re.escape(next_key)})"
        else:
            pattern = rf"{re.escape(key)}\s*(.*)"

        match = re.search(pattern, text, re.DOTALL)
        value = match.group(1).strip() if match else None

        extracted_data[key] = value

    return extracted_data

# %%
# Process each Excel file
for xlsx_file in tqdm(xlsx_files, desc="Processing Excel Files"):
    try:
        # Read the Excel file
        df = pd.read_excel(xlsx_file)

        # Check if 'WEB_ADDRESS' column exists
        if "WEB_ADDRESS" not in df.columns:
            print(f"Skipping {xlsx_file} (No 'WEB_ADDRESS' column found)")
            continue

        # Enable tqdm for pandas
        tqdm.pandas()

        # Fetch webpage text
        df["PAGE_TEXT"] = df["WEB_ADDRESS"].progress_apply(fetch_webpage_text)

        # Define new file name
        new_file_name = os.path.join(r"C:\Users\Nasip-PC\Desktop\Dosyalar\Kodlar\NLP\Data\Processed",xlsx_file.split("\\")[-1])

        # Save to Excel
        df.to_excel(new_file_name, index=False)
        print(f"Saved processed file: {new_file_name}")

    except Exception as e:
        print(f"Error processing {xlsx_file}: {e}")

print("Processing complete!")

# %%
# Get all Excel files in the directory
xlsx_files = glob.glob(os.path.join(r"C:\Users\Nasip-PC\Desktop\Dosyalar\Kodlar\NLP\Data\Processed", "*.xlsx"))
# Define the keys to extract
keys = [
    "Date Initiated by Firm",
    "Date Posted",
    "Recall Status",
    "Recall Number",
    "Recall Event ID",
    "510(K) Number",
    "Product Classification",
    "Product",
    "Code Information",
    "Recalling Firm/Manufacturer",
    "Manufacturer Reason for Recall",
    "FDA Determined Cause",
    "Action",
    "Quantity in Commerce",
    "Distribution",
    "Total Product Life Cycle",
    "Page Last Updated"
]

# %%
# Process each Excel file
for xlsx_file in tqdm(xlsx_files, desc="Processing Excel Files"):
    try:
        # Read the Excel file
        df = pd.read_excel(xlsx_file)

        # Apply the extraction function to PAGE_TEXT
        df_extracted = df["PAGE_TEXT"].apply(lambda text: extract_values(text, keys)).apply(pd.Series)

        # Merge extracted columns back
        df = pd.concat([df, df_extracted], axis=1)

        # Save to Excel
        df.to_excel(xlsx_file, index=False)
        print(f"Saved processed file: {new_file_name}")

    except Exception as e:
        print(f"Error processing {xlsx_file}: {e}")

print("Processing complete!")
# Out:
# Processing Excel Files:  33%|███▎      | 2/6 [00:00<00:00,  5.87it/s]
# Saved processed file: C:\Users\Nasip-PC\Desktop\Dosyalar\Kodlar\NLP\Data\Raw\SoftwreChangeControl_processed.xlsx
# Saved processed file: C:\Users\Nasip-PC\Desktop\Dosyalar\Kodlar\NLP\Data\Raw\SoftwreChangeControl_processed.xlsx
# Processing Excel Files:  67%|██████▋   | 4/6 [00:01<00:00,  3.85it/s]
# Saved processed file: C:\Users\Nasip-PC\Desktop\Dosyalar\Kodlar\NLP\Data\Raw\SoftwreChangeControl_processed.xlsx
# Saved processed file: C:\Users\Nasip-PC\Desktop\Dosyalar\Kodlar\NLP\Data\Raw\SoftwreChangeControl_processed.xlsx
# Processing Excel Files: 100%|██████████| 6/6 [00:01<00:00,  4.91it/s]
# Saved processed file: C:\Users\Nasip-PC\Desktop\Dosyalar\Kodlar\NLP\Data\Raw\SoftwreChangeControl_processed.xlsx
# Saved processed file: C:\Users\Nasip-PC\Desktop\Dosyalar\Kodlar\NLP\Data\Raw\SoftwreChangeControl_processed.xlsx
# Processing Excel Files: 100%|██████████| 6/6 [00:01<00:00,  4.49it/s]
# Processing complete!

# %%
df = pd.read_excel(r"C:\Users\Nasip-PC\Desktop\Dosyalar\Kodlar\NLP\Data\Processed\SoftwareDesign_processed.xlsx")

# %%
df
# Out:
#                                            WEB_ADDRESS RECALL_NUMBER  \
# 0    http://www.accessdata.fda.gov/scripts/cdrh/cfd...   Z-1421-2025
# 1    http://www.accessdata.fda.gov/scripts/cdrh/cfd...   Z-1419-2025
# 2    http://www.accessdata.fda.gov/scripts/cdrh/cfd...   Z-1411-2025
# 3    http://www.accessdata.fda.gov/scripts/cdrh/cfd...   Z-1414-2025
# 4    http://www.accessdata.fda.gov/scripts/cdrh/cfd...   Z-1415-2025
# ..                                                 ...           ...
# 495  http://www.accessdata.fda.gov/scripts/cdrh/cfd...   Z-1685-2021
# 496  http://www.accessdata.fda.gov/scripts/cdrh/cfd...   Z-1772-2021
# 497  http://www.accessdata.fda.gov/scripts/cdrh/cfd...   Z-1771-2021
# 498  http://www.accessdata.fda.gov/scripts/cdrh/cfd...   Z-1692-2021
# 499  http://www.accessdata.fda.gov/scripts/cdrh/cfd...   Z-1693-2021
#
#                                    PRODUCT_DESCRIPTION  \
# 0    Baxter TruSystem 7500 Hybrid MR IMRIS, Product...
# 1    Baxter TruSystem 7500 Hybrid Plus (FC), Produc...
# 2    Baxter Floor mounting column TruSystem 7500, P...
# 3    Baxter Stationary column TruSystem 7500 U, Pro...
# 4    Baxter Floor mounting column TS 7500 U, Produc...
# ..                                                 ...
# 495            Multitom RAX with software version VF10
# 496  MiniMed 670G Insulin Pump:\nModels:\nPUMP MMT-...
# 497  MiniMed 780G Insulin Pump:\nModels:\nPUMP MMT-...
# 498  Critical Care Ventilator, Catalog Number(s): 8...
# 499  Critical Care Ventilator, Catalog Number(s): 8...
#
#                      TRADE_NAME  RECALL_CLASS CENTER CENTER_CLASSIFICATION_DT  \
# 0                       Baxter              2   CDRH               2025-03-21
# 1                       TS 7500             2   CDRH               2025-03-21
# 2                       TS 7500             2   CDRH               2025-03-21
# 3                       TS 7500             2   CDRH               2025-03-21
# 4                       TS 7500             2   CDRH               2025-03-21
# ..                          ...           ...    ...                      ...
# 495                Multitom RAX             2   CDRH               2021-06-02
# 496   MiniMed 670G Insulin Pump             2   CDRH               2021-06-01
# 497  MiniMed" 780G Insulin Pump             2   CDRH               2021-06-01
# 498    Babylog VN600 Ventilator             2   CDRH               2021-05-28
# 499    Babylog VN800 Ventilator             2   CDRH               2021-05-28
#
#      POSTED_INTERNET_DT      TERMINATION_DT  \
# 0   2025-03-21 21:06:30                 NaT
# 1   2025-03-21 21:06:30                 NaT
# 2   2025-03-21 21:06:30                 NaT
# 3   2025-03-21 21:06:30                 NaT
# 4   2025-03-21 21:06:30                 NaT
# ..                  ...                 ...
# 495                 NaT 2023-11-08 10:03:16
# 496                 NaT                 NaT
# 497                 NaT                 NaT
# 498                 NaT 2024-02-06 08:42:57
# 499                 NaT 2024-02-06 08:42:57
#
#                               FIRM_NAME  ...  \
# 0         Baxter Healthcare Corporation  ...
# 1         Baxter Healthcare Corporation  ...
# 2         Baxter Healthcare Corporation  ...
# 3         Baxter Healthcare Corporation  ...
# 4         Baxter Healthcare Corporation  ...
# ..                                  ...  ...
# 495  Siemens Medical Solutions USA, Inc  ...
# 496                   Medtronic Minimed  ...
# 497                   Medtronic Minimed  ...
# 498               Draeger Medical, Inc.  ...
# 499               Draeger Medical, Inc.  ...
#
#                                                Product Code Information  \
# 0    s Vaccines, Blood & Biologics Animal & Veterin...              NaN
# 1    s Vaccines, Blood & Biologics Animal & Veterin...              NaN
# 2    s Vaccines, Blood & Biologics Animal & Veterin...              NaN
# 3    s Vaccines, Blood & Biologics Animal & Veterin...              NaN
# 4    s Vaccines, Blood & Biologics Animal & Veterin...              NaN
# ..                                                 ...              ...
# 495                                                NaN              NaN
# 496                                                NaN              NaN
# 497                                                NaN              NaN
# 498                                                NaN              NaN
# 499                                                NaN              NaN
#
#     Recalling Firm/Manufacturer  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ..                          ...
# 495                         NaN
# 496                         NaN
# 497                         NaN
# 498                         NaN
# 499                         NaN
#
#                         Manufacturer Reason for Recall FDA Determined Cause  \
# 0    There is a software issue which causes the upp...    2 Software design
# 1    There is a software issue which causes the upp...    2 Software design
# 2    There is a software issue which causes the upp...    2 Software design
# 3    There is a software issue which causes the upp...    2 Software design
# 4    There is a software issue which causes the upp...    2 Software design
# ..                                                 ...                  ...
# 495                                                NaN                  NaN
# 496                                                NaN                  NaN
# 497                                                NaN                  NaN
# 498                                                NaN                  NaN
# 499                                                NaN                  NaN
#
#                                                 Action  Quantity in Commerce  \
# 0    Baxter issued an UREGENT MEDICAL DEVICE CORREC...              24 units
# 1    Baxter issued an UREGENT MEDICAL DEVICE CORREC...              93 units
# 2    Baxter issued an UREGENT MEDICAL DEVICE CORREC...             112 units
# 3    Baxter issued an UREGENT MEDICAL DEVICE CORREC...               2 units
# 4    Baxter issued an UREGENT MEDICAL DEVICE CORREC...              33 units
# ..                                                 ...                   ...
# 495                                                NaN                   NaN
# 496                                                NaN                   NaN
# 497                                                NaN                   NaN
# 498                                                NaN                   NaN
# 499                                                NaN                   NaN
#
#                     Distribution  \
# 0    US Nationwide distribution.
# 1    US Nationwide distribution.
# 2    US Nationwide distribution.
# 3    US Nationwide distribution.
# 4    US Nationwide distribution.
# ..                           ...
# 495                          NaN
# 496                          NaN
# 497                          NaN
# 498                          NaN
# 499                          NaN
#
#                               Total Product Life Cycle  \
# 0    TPLC Device Report 1 A record in this database...
# 1    TPLC Device Report 1 A record in this database...
# 2    TPLC Device Report 1 A record in this database...
# 3    TPLC Device Report 1 A record in this database...
# 4    TPLC Device Report 1 A record in this database...
# ..                                                 ...
# 495                                                NaN
# 496                                                NaN
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
#
#                                      Page Last Updated
# 0    : 03/21/2025 Note: If you need help accessing ...
# 1    : 03/21/2025 Note: If you need help accessing ...
# 2    : 03/21/2025 Note: If you need help accessing ...
# 3    : 03/21/2025 Note: If you need help accessing ...
# 4    : 03/21/2025 Note: If you need help accessing ...
# ..                                                 ...
# 495                                                NaN
# 496                                                NaN
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
#
# [500 rows x 29 columns]

# %%
df["WEB_ADDRESS"].value_counts()
# Out:
# WEB_ADDRESS
# http://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfres/res.cfm?id=212489    1
# http://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfres/res.cfm?id=193552    1
# http://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfres/res.cfm?id=192851    1
# http://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfres/res.cfm?id=192627    1
# http://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfres/res.cfm?id=192103    1
#                                                                             ..
# http://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfres/res.cfm?id=207143    1
# http://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfres/res.cfm?id=207133    1
# http://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfres/res.cfm?id=207144    1
# http://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfres/res.cfm?id=207141    1
# http://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfres/res.cfm?id=187116    1
# Name: count, Length: 500, dtype: int64
